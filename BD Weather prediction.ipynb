# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('65 Years of Weather Data Bangladesh (1948 - 2013).csv')
df.head()
# Out:
#    Unnamed: 0 Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  \
# 0           0       Barisal  1949      1      29.4      12.3       0.0
# 1           1       Barisal  1950      1      30.0      14.1       0.0
# 2           2       Barisal  1951      1      28.2      12.3       0.0
# 3           3       Barisal  1952      1      26.6      12.3       2.0
# 4           4       Barisal  1953      1      30.0      13.3      10.0
#
#    Relative Humidity  Wind Speed  Cloud Coverage  Bright Sunshine  \
# 0               68.0    0.453704             0.6         7.831915
# 1               77.0    0.453704             0.8         7.831915
# 2               77.0    0.453704             0.6         7.831915
# 3               77.0    0.453704             1.0         7.831915
# 4               75.0    0.453704             1.6         7.831915
#
#    Station Number     X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period
# 0           41950  536809.8  510151.9      22.7      90.36    4  1949.01
# 1           41950  536809.8  510151.9      22.7      90.36    4  1950.01
# 2           41950  536809.8  510151.9      22.7      90.36    4  1951.01
# 3           41950  536809.8  510151.9      22.7      90.36    4  1952.01
# 4           41950  536809.8  510151.9      22.7      90.36    4  1953.01

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Station Names', 'YEAR', 'Month', 'Max Temp', 'Min Temp',
#        'Rainfall', 'Relative Humidity', 'Wind Speed', 'Cloud Coverage',
#        'Bright Sunshine', 'Station Number', 'X_COR', 'Y_COR', 'LATITUDE',
#        'LONGITUDE', 'ALT', 'Period'],
#       dtype='object')

# %%
cols = ['Station Names', 'YEAR', 'Month', 'Max Temp', 'Min Temp',
       'Rainfall', 'Relative Humidity', 'Wind Speed', 'Cloud Coverage',
       'Bright Sunshine', 'Station Number', 'X_COR', 'Y_COR', 'LATITUDE',
       'LONGITUDE', 'ALT', 'Period']
df = df[cols]
df.head()
# Out:
#   Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  Relative Humidity  \
# 0       Barisal  1949      1      29.4      12.3       0.0               68.0
# 1       Barisal  1950      1      30.0      14.1       0.0               77.0
# 2       Barisal  1951      1      28.2      12.3       0.0               77.0
# 3       Barisal  1952      1      26.6      12.3       2.0               77.0
# 4       Barisal  1953      1      30.0      13.3      10.0               75.0
#
#    Wind Speed  Cloud Coverage  Bright Sunshine  Station Number     X_COR  \
# 0    0.453704             0.6         7.831915           41950  536809.8
# 1    0.453704             0.8         7.831915           41950  536809.8
# 2    0.453704             0.6         7.831915           41950  536809.8
# 3    0.453704             1.0         7.831915           41950  536809.8
# 4    0.453704             1.6         7.831915           41950  536809.8
#
#       Y_COR  LATITUDE  LONGITUDE  ALT   Period
# 0  510151.9      22.7      90.36    4  1949.01
# 1  510151.9      22.7      90.36    4  1950.01
# 2  510151.9      22.7      90.36    4  1951.01
# 3  510151.9      22.7      90.36    4  1952.01
# 4  510151.9      22.7      90.36    4  1953.01

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#   station names  year  month  max temp  min temp  rainfall  relative humidity  \
# 0       Barisal  1949      1      29.4      12.3       0.0               68.0
# 1       Barisal  1950      1      30.0      14.1       0.0               77.0
# 2       Barisal  1951      1      28.2      12.3       0.0               77.0
# 3       Barisal  1952      1      26.6      12.3       2.0               77.0
# 4       Barisal  1953      1      30.0      13.3      10.0               75.0
#
#    wind speed  cloud coverage  bright sunshine  station number     x_cor  \
# 0    0.453704             0.6         7.831915           41950  536809.8
# 1    0.453704             0.8         7.831915           41950  536809.8
# 2    0.453704             0.6         7.831915           41950  536809.8
# 3    0.453704             1.0         7.831915           41950  536809.8
# 4    0.453704             1.6         7.831915           41950  536809.8
#
#       y_cor  latitude  longitude  alt   period
# 0  510151.9      22.7      90.36    4  1949.01
# 1  510151.9      22.7      90.36    4  1950.01
# 2  510151.9      22.7      90.36    4  1951.01
# 3  510151.9      22.7      90.36    4  1952.01
# 4  510151.9      22.7      90.36    4  1953.01

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#   station_names  year  month  max_temp  min_temp  rainfall  relative_humidity  \
# 0       Barisal  1949      1      29.4      12.3       0.0               68.0
# 1       Barisal  1950      1      30.0      14.1       0.0               77.0
# 2       Barisal  1951      1      28.2      12.3       0.0               77.0
# 3       Barisal  1952      1      26.6      12.3       2.0               77.0
# 4       Barisal  1953      1      30.0      13.3      10.0               75.0
#
#    wind_speed  cloud_coverage  bright_sunshine  station_number     x_cor  \
# 0    0.453704             0.6         7.831915           41950  536809.8
# 1    0.453704             0.8         7.831915           41950  536809.8
# 2    0.453704             0.6         7.831915           41950  536809.8
# 3    0.453704             1.0         7.831915           41950  536809.8
# 4    0.453704             1.6         7.831915           41950  536809.8
#
#       y_cor  latitude  longitude  alt   period
# 0  510151.9      22.7      90.36    4  1949.01
# 1  510151.9      22.7      90.36    4  1950.01
# 2  510151.9      22.7      90.36    4  1951.01
# 3  510151.9      22.7      90.36    4  1952.01
# 4  510151.9      22.7      90.36    4  1953.01

# %%
df.head()
# Out:
#   station_names  year  month  max_temp  min_temp  rainfall  relative_humidity  \
# 0       Barisal  1949      1      29.4      12.3       0.0               68.0
# 1       Barisal  1950      1      30.0      14.1       0.0               77.0
# 2       Barisal  1951      1      28.2      12.3       0.0               77.0
# 3       Barisal  1952      1      26.6      12.3       2.0               77.0
# 4       Barisal  1953      1      30.0      13.3      10.0               75.0
#
#    wind_speed  cloud_coverage  bright_sunshine  station_number     x_cor  \
# 0    0.453704             0.6         7.831915           41950  536809.8
# 1    0.453704             0.8         7.831915           41950  536809.8
# 2    0.453704             0.6         7.831915           41950  536809.8
# 3    0.453704             1.0         7.831915           41950  536809.8
# 4    0.453704             1.6         7.831915           41950  536809.8
#
#       y_cor  latitude  longitude  alt   period
# 0  510151.9      22.7      90.36    4  1949.01
# 1  510151.9      22.7      90.36    4  1950.01
# 2  510151.9      22.7      90.36    4  1951.01
# 3  510151.9      22.7      90.36    4  1952.01
# 4  510151.9      22.7      90.36    4  1953.01

# %%
df.isnull().sum()
# Out:
# station_names        0
# year                 0
# month                0
# max_temp             0
# min_temp             0
# rainfall             0
# relative_humidity    0
# wind_speed           0
# cloud_coverage       0
# bright_sunshine      0
# station_number       0
# x_cor                0
# y_cor                0
# latitude             0
# longitude            0
# alt                  0
# period               0
# dtype: int64

# %%
df['date'] = pd.to_datetime({'year':df['year'],'month':df['month'],'day':1})
df.head()
# Out:
#   station_names  year  month  max_temp  min_temp  rainfall  relative_humidity  \
# 0       Barisal  1949      1      29.4      12.3       0.0               68.0
# 1       Barisal  1950      1      30.0      14.1       0.0               77.0
# 2       Barisal  1951      1      28.2      12.3       0.0               77.0
# 3       Barisal  1952      1      26.6      12.3       2.0               77.0
# 4       Barisal  1953      1      30.0      13.3      10.0               75.0
#
#    wind_speed  cloud_coverage  bright_sunshine  station_number     x_cor  \
# 0    0.453704             0.6         7.831915           41950  536809.8
# 1    0.453704             0.8         7.831915           41950  536809.8
# 2    0.453704             0.6         7.831915           41950  536809.8
# 3    0.453704             1.0         7.831915           41950  536809.8
# 4    0.453704             1.6         7.831915           41950  536809.8
#
#       y_cor  latitude  longitude  alt   period       date
# 0  510151.9      22.7      90.36    4  1949.01 1949-01-01
# 1  510151.9      22.7      90.36    4  1950.01 1950-01-01
# 2  510151.9      22.7      90.36    4  1951.01 1951-01-01
# 3  510151.9      22.7      90.36    4  1952.01 1952-01-01
# 4  510151.9      22.7      90.36    4  1953.01 1953-01-01

# %%
df.set_index('date',inplace=True)
df.head()
# Out:
#            station_names  year  month  max_temp  min_temp  rainfall  \
# date
# 1949-01-01       Barisal  1949      1      29.4      12.3       0.0
# 1950-01-01       Barisal  1950      1      30.0      14.1       0.0
# 1951-01-01       Barisal  1951      1      28.2      12.3       0.0
# 1952-01-01       Barisal  1952      1      26.6      12.3       2.0
# 1953-01-01       Barisal  1953      1      30.0      13.3      10.0
#
#             relative_humidity  wind_speed  cloud_coverage  bright_sunshine  \
# date
# 1949-01-01               68.0    0.453704             0.6         7.831915
# 1950-01-01               77.0    0.453704             0.8         7.831915
# 1951-01-01               77.0    0.453704             0.6         7.831915
# 1952-01-01               77.0    0.453704             1.0         7.831915
# 1953-01-01               75.0    0.453704             1.6         7.831915
#
#             station_number     x_cor     y_cor  latitude  longitude  alt  \
# date
# 1949-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1950-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1951-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1952-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1953-01-01           41950  536809.8  510151.9      22.7      90.36    4
#
#              period
# date
# 1949-01-01  1949.01
# 1950-01-01  1950.01
# 1951-01-01  1951.01
# 1952-01-01  1952.01
# 1953-01-01  1953.01

# %%
df['average_temperature'] = (df['max_temp']+df['min_temp'])/2
df.head()
# Out:
#            station_names  year  month  max_temp  min_temp  rainfall  \
# date
# 1949-01-01       Barisal  1949      1      29.4      12.3       0.0
# 1950-01-01       Barisal  1950      1      30.0      14.1       0.0
# 1951-01-01       Barisal  1951      1      28.2      12.3       0.0
# 1952-01-01       Barisal  1952      1      26.6      12.3       2.0
# 1953-01-01       Barisal  1953      1      30.0      13.3      10.0
#
#             relative_humidity  wind_speed  cloud_coverage  bright_sunshine  \
# date
# 1949-01-01               68.0    0.453704             0.6         7.831915
# 1950-01-01               77.0    0.453704             0.8         7.831915
# 1951-01-01               77.0    0.453704             0.6         7.831915
# 1952-01-01               77.0    0.453704             1.0         7.831915
# 1953-01-01               75.0    0.453704             1.6         7.831915
#
#             station_number     x_cor     y_cor  latitude  longitude  alt  \
# date
# 1949-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1950-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1951-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1952-01-01           41950  536809.8  510151.9      22.7      90.36    4
# 1953-01-01           41950  536809.8  510151.9      22.7      90.36    4
#
#              period  average_temperature
# date
# 1949-01-01  1949.01                20.85
# 1950-01-01  1950.01                22.05
# 1951-01-01  1951.01                20.25
# 1952-01-01  1952.01                19.45
# 1953-01-01  1953.01                21.65

# %%
df_dhk = df[df['station_names']=='Dhaka']

# %%
df_dhk = df_dhk.sort_index()

# %%
df_dhk
# Out:
#            station_names  year  month  max_temp  min_temp  rainfall  \
# date
# 1953-01-01         Dhaka  1953      1      26.7      10.9      10.0
# 1953-02-01         Dhaka  1953      2      33.6      14.7       2.0
# 1953-03-01         Dhaka  1953      3      37.5      21.7      90.0
# 1953-04-01         Dhaka  1953      4      37.7      23.4      90.0
# 1953-05-01         Dhaka  1953      5      34.7      24.2     274.0
# ...                  ...   ...    ...       ...       ...       ...
# 2013-08-01         Dhaka  2013      8      35.0      26.2     212.0
# 2013-09-01         Dhaka  2013      9      35.7      26.3     172.0
# 2013-10-01         Dhaka  2013     10      35.2      24.4     131.0
# 2013-11-01         Dhaka  2013     11      32.1      18.5       0.0
# 2013-12-01         Dhaka  2013     12      30.5      15.6       4.0
#
#             relative_humidity  wind_speed  cloud_coverage  bright_sunshine  \
# date
# 1953-01-01               70.0    0.725926             1.7         7.343396
# 1953-02-01               65.0    0.924074             2.1         8.130189
# 1953-03-01               73.0    1.403704             3.7         8.211321
# 1953-04-01               69.0    2.137037             3.4         8.132075
# 1953-05-01               81.0    1.855556             5.8         7.343396
# ...                       ...         ...             ...              ...
# 2013-08-01               81.0    2.500000             6.3         3.300000
# 2013-09-01               81.0    1.800000             5.8         3.600000
# 2013-10-01               79.0    1.800000             4.9         4.500000
# 2013-11-01               67.0    1.700000             0.9         7.000000
# 2013-12-01               73.0    1.600000             1.2         4.100000
#
#             station_number     x_cor     y_cor  latitude  longitude  alt  \
# date
# 1953-01-01           41923  540098.6  629248.4     23.78      90.39    9
# 1953-02-01           41923  540098.6  629248.4     23.78      90.39    9
# 1953-03-01           41923  540098.6  629248.4     23.78      90.39    9
# 1953-04-01           41923  540098.6  629248.4     23.78      90.39    9
# 1953-05-01           41923  540098.6  629248.4     23.78      90.39    9
# ...                    ...       ...       ...       ...        ...  ...
# 2013-08-01           41923  540098.6  629248.4     23.78      90.39    9
# 2013-09-01           41923  540098.6  629248.4     23.78      90.39    9
# 2013-10-01           41923  540098.6  629248.4     23.78      90.39    9
# 2013-11-01           41923  540098.6  629248.4     23.78      90.39    9
# 2013-12-01           41923  540098.6  629248.4     23.78      90.39    9
#
#              period  average_temperature
# date
# 1953-01-01  1953.01                18.80
# 1953-02-01  1953.02                24.15
# 1953-03-01  1953.03                29.60
# 1953-04-01  1953.04                30.55
# 1953-05-01  1953.05                29.45
# ...             ...                  ...
# 2013-08-01  2013.08                30.60
# 2013-09-01  2013.09                31.00
# 2013-10-01  2013.10                29.80
# 2013-11-01  2013.11                25.30
# 2013-12-01  2013.12                23.05
#
# [732 rows x 18 columns]

# %%
plt.figure(figsize=(16,6))
df_dhk['average_temperature'].plot(colormap='viridis')
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Forecasting the average temperature in DHAKA

# %%
df_dhk.head(2)
# Out:
#            station_names  year  month  max_temp  min_temp  rainfall  \
# date
# 1953-01-01         Dhaka  1953      1      26.7      10.9      10.0
# 1953-02-01         Dhaka  1953      2      33.6      14.7       2.0
#
#             relative_humidity  wind_speed  cloud_coverage  bright_sunshine  \
# date
# 1953-01-01               70.0    0.725926             1.7         7.343396
# 1953-02-01               65.0    0.924074             2.1         8.130189
#
#             station_number     x_cor     y_cor  latitude  longitude  alt  \
# date
# 1953-01-01           41923  540098.6  629248.4     23.78      90.39    9
# 1953-02-01           41923  540098.6  629248.4     23.78      90.39    9
#
#              period  average_temperature
# date
# 1953-01-01  1953.01                18.80
# 1953-02-01  1953.02                24.15

# %%
df_dhk.index.freq='MS'

# %%
dhk = df_dhk[['average_temperature']]
dhk
# Out:
#             average_temperature
# date
# 1953-01-01                18.80
# 1953-02-01                24.15
# 1953-03-01                29.60
# 1953-04-01                30.55
# 1953-05-01                29.45
# ...                         ...
# 2013-08-01                30.60
# 2013-09-01                31.00
# 2013-10-01                29.80
# 2013-11-01                25.30
# 2013-12-01                23.05
#
# [732 rows x 1 columns]

# %%
# AD Test

from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(dhk['average_temperature'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -2.916004
# p-value                   0.043518
# # lags used              13.000000
# # observations          718.000000
# critical value (1%)      -3.439490
# critical value (5%)      -2.865574
# critical value (10%)     -2.568918
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
from pmdarima import auto_arima
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA,ARMA,ARIMAResults,ARMAResults

# %%
result = seasonal_decompose(dhk['average_temperature'])
result.plot();

# %%
result.seasonal.plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
auto_arima(dhk['average_temperature'],seasonal=False,trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3007.768, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3437.978, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3226.475, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3208.029, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3435.982, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3153.798, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3183.947, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2804.460, Time=0.85 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=2741.564, Time=0.88 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=2677.294, Time=0.98 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=2570.691, Time=0.99 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=2721.454, Time=0.46 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=inf, Time=0.98 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#
# Best model:  ARIMA(2,1,5)(0,0,0)[0]
# Total fit time: 15.304 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  732
# Model:               SARIMAX(2, 1, 5)   Log Likelihood               -1277.346
# Date:                Sun, 11 Apr 2021   AIC                           2570.691
# Time:                        04:07:38   BIC                           2607.446
# Sample:                             0   HQIC                          2584.871
#                                 - 732
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.7224      0.005    353.644      0.000       1.713       1.732
# ar.L2         -0.9894      0.004   -224.437      0.000      -0.998      -0.981
# ma.L1         -1.9286      0.038    -50.214      0.000      -2.004      -1.853
# ma.L2          0.7754      0.089      8.706      0.000       0.601       0.950
# ma.L3          0.2686      0.090      2.982      0.003       0.092       0.445
# ma.L4          0.2600      0.082      3.188      0.001       0.100       0.420
# ma.L5         -0.3700      0.036    -10.300      0.000      -0.440      -0.300
# sigma2         1.8921      0.108     17.480      0.000       1.680       2.104
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 1.07
# Prob(Q):                              0.74   Prob(JB):                         0.59
# Heteroskedasticity (H):               1.03   Skew:                             0.05
# Prob(H) (two-sided):                  0.80   Kurtosis:                         2.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
len(dhk)
# Out:
# 732

# %%
train = dhk.iloc[:708]
test = dhk.iloc[708:]

# %%
model = ARIMA(train['average_temperature'],order=(2,1,5))
results = model.fit()

# %%
start = len(train)
end = len(train)+len(test)-1
prediction = results.predict(start,end,typ='levels').rename('Prediction of test data')

# %%
test['average_temperature'].plot(figsize=(16,8),legend=True,linewidth=5.0,color='red')
prediction.plot(legend=True,linewidth=5.0,color='green')
plt.title('MODEL EVALUATION USING TEST DATA(24 MONTHS)',fontsize=20,style='italic',fontweight='bold')
plt.xlabel('Time Horizon From Jan,2012 to Dec,2013',fontsize=14)
plt.ylabel('Average Temperature In Dhaka',fontsize=14)
# Out:
# Text(0, 0.5, 'Average Temperature In Dhaka')

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(test['average_temperature'],prediction)
MSE
# Out:
# 3.106620248152248

# %%
root_mean_square_error = np.sqrt(MSE)
root_mean_square_error
# Out:
# 1.7625607076501644

# %% [markdown]
# ## Our prediction is pretty impressive with rmse=1.76 only

# %% [markdown]
# ## Forecast into the unknown future

# %%
mdoel = ARIMA(dhk['average_temperature'],order=(2,1,5))
results = model.fit()

# %%
start = len(train)
end = len(train)+47
prediction = results.predict(start,end,typ='levels').rename('Forecast next 24 months ')

# %%
dhk['average_temperature'].loc['2010-01-01':].plot(figsize=(19,8),legend=True,color='crimson',linewidth=4.5)
prediction.plot(legend=True,color='green',linewidth=4.5)
plt.title('FORCASTING(24 MONTHS)',fontsize=20,style='italic',fontweight='bold')
plt.xlabel('Time Horizon From Jan,2014 to Dec,2015',fontsize=14)
plt.ylabel('Average Temperature In Dhaka',fontsize=14)
# Out:
# Text(0, 0.5, 'Average Temperature In Dhaka')

# %% [markdown]
# ## EDA

# %%
df['month_name']=df['date'].dt.strftime('%b')

# %%
df['month_name']
# Out:
# 0        Jan
# 1        Jan
# 2        Jan
# 3        Jan
# 4        Jan
#         ...
# 21115    Dec
# 21116    Dec
# 21117    Dec
# 21118    Dec
# 21119    Dec
# Name: month_name, Length: 21120, dtype: object

# %%
plt.figure(figsize=(14,8))
df.groupby(by='month_name')['average_temperature'].mean().plot(kind='bar',colormap='Paired',linewidth=2.9,edgecolor='red')
plt.xlabel('Month')
plt.ylabel('Average temperature')
plt.title('AVERAGE TEMPERATURE IN DIFFERENT MONTHS',fontsize=20,style='italic',fontweight='bold')
plt.xticks(rotation=80);

# %%
plt.figure(figsize=(14,8))
df.groupby(by='month_name')['rainfall'].mean().plot(kind='bar',colormap='Accent',linewidth=2.9,edgecolor='red')
plt.xlabel('Month')
plt.ylabel('Average rainfall')
plt.title('AVERAGE RAINFALL IN DIFFERENT MONTHS',fontsize=20,style='italic',fontweight='bold')
plt.xticks(rotation=80);

# %%
plt.figure(figsize=(16,12))
df.groupby(by='station_names')['rainfall'].mean().sort_values(ascending=True).plot(kind='bar',
                                                                                    colormap='Dark2',
                                                                                    linewidth=2.9,
                                                                                    edgecolor='k')
plt.xlabel('District')
plt.ylabel('Average rainfall')
plt.title('AVERAGE RAINFALL IN DIFFERENT PARTS OF THE COUNTRY',fontsize=20,style='italic',fontweight='bold')
plt.xticks(rotation=80);

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12,12))
sns.boxplot(y=df['station_names'],x=df['average_temperature'],orient='h')
plt.title('AVERAGE TEMPERATURE IN DIFFERENT PARTS OF BANGLADESH',fontsize=20,style='italic',fontweight='bold')
plt.xlabel('Average temperature',fontsize=16)
plt.ylabel('District',fontsize=16)
# Out:
# Text(0, 0.5, 'District')

# %% [markdown]
# ## THANKS FOR VIEWING MY REPOSITORY
